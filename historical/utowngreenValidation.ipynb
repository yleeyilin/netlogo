# %%
# import dependencies
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd

# %%
# load data
utown_observed = pd.read_csv('/Users/leeyilin/Downloads/netlogo/data/recorded/utownrecorded.csv').sample(n=8)
utown_predicted = pd.read_csv('/Users/leeyilin/Downloads/netlogo/data/model/utown.csv').sample(n=8)

# %%
# view observed courtyard data
utown_observed.head()
# Out:
#     Category  air temp  ground temp
# 12     15000      34.1         34.2
# 1       1300      31.7         32.7
# 8       8400      32.7         36.8
# 0          0      32.9         33.3
# 13     18000      32.4         35.3

# %%
# view predicted courtyard data
utown_predicted.head()
# Out:
#        Category   air temp  ground temp
# 424         424  32.102564    28.571429
# 2695       2695  33.000000    26.904762
# 5757       5757  31.205128    25.476190
# 17191     17191  34.666667    27.380952
# 16900     16900  31.589744    27.142857

# %%
# extract values from observed and model values
x1 = utown_observed['Category'].values.reshape(-1, 1)
y1 = utown_observed['air temp'].values

x2 = utown_predicted['Category'].values.reshape(-1, 1)
y2 = utown_predicted['air temp'].values

# plot scatterplot
plt.scatter(x1, y1, color='blue', label='Scatterplot (Observation)')
plt.scatter(x2, y2, color='red', label='Scatterplot (NetLogo)')

# fit linear regression
model1 = LinearRegression()
model2 = LinearRegression()
model1.fit(x1, y1)
model2.fit(x2, y2)
y_pred1 = model1.predict(x1)
y_pred2 = model2.predict(x2)

# plot regression line
plt.plot(x1, y_pred1, color='green', linestyle='-', linewidth=2, label='Linear Regression (Observation)')
plt.plot(x2, y_pred2, color='orange', linestyle='-', linewidth=2, label='Linear Regression (NetLogo)')

# add labels and titles to plot
plt.xlabel('Time')
plt.ylabel('Air Temperature')
plt.title('UTown Green Air Temperature in NetLogo vs Observed')
plt.legend()

# show plot
plt.show()
